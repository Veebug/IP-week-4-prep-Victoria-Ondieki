# %% [markdown]
# <a href="https://colab.research.google.com/github/Veebug/IP-week-4-prep-Victoria-Ondieki/blob/main/IP_week_4_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("http://bit.ly/autolib_dataset")
data.head(10)
# Out:
#                               Address  Cars  Bluecar counter  ...  day  hour  minute
# 0                 2 Avenue de Suffren     0                0  ...    8    11      43
# 1           145 Rue Raymond Losserand     6                6  ...    6     7      24
# 2    2 Avenue John Fitzgerald Kennedy     3                3  ...    3    20      14
# 3              51 Rue Eug̬ne Oudin̩     3                3  ...    4     4      37
# 4  6 avenue de la Porte de Champerret     3                3  ...    8    17      23
# 5                8 Boulevard Voltaire     0                0  ...    6     7       2
# 6                      37 rue Leblanc     0                0  ...    8    18      20
# 7         17 Rue des Luaps Prolong̩e     3                3  ...    4    22      13
# 8               34 avenue Jean Moulin     1                1  ...    2    22      58
# 9        41 boulevard de Rochechouart     6                6  ...    4    15       2
#
# [10 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
data.isnull().any()
# Out:
# Address                False
# Cars                   False
# Bluecar counter        False
# Utilib counter         False
# Utilib 1.4 counter     False
# Charge Slots           False
# Charging Status        False
# City                   False
# Displayed comment       True
# ID                     False
# Kind                   False
# Geo point              False
# Postal code            False
# Public name            False
# Rental status          False
# Scheduled at            True
# Slots                  False
# Station type           False
# Status                 False
# Subscription status    False
# year                   False
# month                  False
# day                    False
# hour                   False
# minute                 False
# dtype: bool

# %%
#drop display column
data.drop(["Displayed comment","Scheduled at"],inplace=True,axis=1)

# %%
#checking for duplicates
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
data.groupby(["City"]).tail(2)
# Out:
#                           Address  Cars  Bluecar counter  ...  day  hour  minute
# 542         28 Route d'Argenteuil     0                0  ...    4     9      37
# 1492           6 avenue du Mesnil     1                1  ...    6     6      39
# 2147                87 rue Martre     4                4  ...    9     1      32
# 2348  45 rue du G̩n̩ral Leclerc     2                2  ...    5    18      54
# 2358    2 Place Charles de Gaulle     3                3  ...    5     5      10
# ...                           ...   ...              ...  ...  ...   ...     ...
# 4993   6 avenue Charles-de-Gaulle     6                6  ...    2     4      43
# 4995          8 avenue M̩nelotte     2                2  ...    6    11      26
# 4997               142 rue du Bac     1                1  ...    1     7       1
# 4998  2 avenue du Val de Fontenay     2                2  ...    4    17      27
# 4999          5 Rue Henry Brisson     4                4  ...    8    10       2
#
# ...

# %%
data.to_csv("cleandata")
